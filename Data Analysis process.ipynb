# %% [markdown]
# # Gathering Data & Reading File

# %%
import numpy as np

counts= [1,2,3,4,5,6,7,8,9]

means = np.mean(counts)
print(means)
# Out:
# 5.0

# %%
import pandas as pd 

df = pd.read_csv("data.csv")

df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# print the column labels in the dataframe
# View the index number and label for each column
for i, v in enumerate(df.columns):
    print(i, v)
# Out:
# 0 id
# 1 diagnosis
# 2 radius_mean
# 3 texture_mean
# 4 perimeter_mean
# 5 area_mean
# 6 smoothness_mean
# 7 compactness_mean
# 8 concavity_mean
# 9 concave points_mean
# 10 symmetry_mean
# 11 fractal_dimension_mean
# 12 radius_se
# 13 texture_se
# 14 perimeter_se
# 15 area_se
# 16 smoothness_se
# 17 compactness_se
# 18 concavity_se
# 19 concave points_se
# 20 symmetry_se
# 21 fractal_dimension_se
# 22 radius_worst
# 23 texture_worst
# 24 perimeter_worst
# 25 area_worst
# 26 smoothness_worst
# 27 compactness_worst
# 28 concavity_worst
# 29 concave points_worst
# 30 symmetry_worst
# 31 fractal_dimension_worst
# 32 Unnamed: 32

# %%
df = pd.read_csv("data.csv", header=2)
df.head()
# Here, row 2 was used as the the header and everything above that was cut off. By default, read_csv uses header=0, which uses the first line for column labels.
# Out:
#      842517  M  20.57  17.77   132.9    1326  0.08474  0.07864  0.0869  \
# 0  84300903  M  19.69  21.25  130.00  1203.0  0.10960   0.1599  0.1974
# 1  84348301  M  11.42  20.38   77.58   386.1  0.14250   0.2839  0.2414
# 2  84358402  M  20.29  14.34  135.10  1297.0  0.10030   0.1328  0.1980
# 3    843786  M  12.45  15.70   82.57   477.1  0.12780   0.1700  0.1578
# 4    844359  M  18.25  19.98  119.60  1040.0  0.09463   0.1090  0.1127
#
#    0.07017  ...  24.99  23.41   158.8    1956  0.1238  0.1866  0.2416   0.186  \
# 0  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 1  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 2  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
# 3  0.08089  ...  15.47  23.75  103.40   741.6  0.1791  0.5249  0.5355  0.1741
# 4  0.07400  ...  22.88  27.66  153.20  1606.0  0.1442  0.2576  0.3784  0.1932
#
#     0.275  0.08902
# 0  0.3613  0.08758
# 1  0.6638  0.17300
# ...

# %%
label = ['number', 'male', 'age', 'extra', 'extras']
df = pd.read_csv("data.csv", names=label, header= 0)
# if you remove header = 0 the names of the label will be above the older name 
df.head()
# Out:
#                                                                                                                                                                                                          number  \
# 842302   M 17.99 10.38 122.80 1001.0 0.11840 0.27760 0.3001 0.14710 0.2419 0.07871 1.0950 0.9053 8.589 153.40 0.006399 0.04904 0.05373 0.01587 0.03003 0.006193 25.38 17.33 184.60 2019.0 0.1622 0.6656  0.7119
# 842517   M 20.57 17.77 132.90 1326.0 0.08474 0.07864 0.0869 0.07017 0.1812 0.05667 0.5435 0.7339 3.398 74.08  0.005225 0.01308 0.01860 0.01340 0.01389 0.003532 24.99 23.41 158.80 1956.0 0.1238 0.1866  0.2416
# 84300903 M 19.69 21.25 130.00 1203.0 0.10960 0.15990 0.1974 0.12790 0.2069 0.05999 0.7456 0.7869 4.585 94.03  0.006150 0.04006 0.03832 0.02058 0.02250 0.004571 23.57 25.53 152.50 1709.0 0.1444 0.4245  0.4504
# ...

# %%
df = pd.read_csv('data.csv', index_col=['diagnosis'])
df.head()
# to make the colunm first just write the name of it inside index_col
# you can put more than 1
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# diagnosis
# M            842302        17.99         10.38          122.80     1001.0
# M            842517        20.57         17.77          132.90     1326.0
# M          84300903        19.69         21.25          130.00     1203.0
# M          84348301        11.42         20.38           77.58      386.1
# M          84358402        20.29         14.34          135.10     1297.0
#
#            smoothness_mean  compactness_mean  concavity_mean  \
# diagnosis
# M                  0.11840           0.27760          0.3001
# M                  0.08474           0.07864          0.0869
# M                  0.10960           0.15990          0.1974
# M                  0.14250           0.28390          0.2414
# M                  0.10030           0.13280          0.1980
#
#            concave points_mean  symmetry_mean  ...  texture_worst  \
# diagnosis                                      ...
# ...

# %%
df.shape
# this returns a tuple of the dimensions of the dataframe
# Out:
# (569, 32)

# %%
df.dtypes
# this returns the datatypes of the columns
# Out:
# id                           int64
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# ...

# %%
import pandas as pd

df = pd.read_csv('data.csv')
# although the datatype for diagnosis appears to be object, further
# investigation shows it's a string
type(df['diagnosis'][0])
# Out:
# str

# %%
df.info()
# this displays a concise summary of the dataframe,
# including the number of non-null values in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.nunique()
# this returns the number of unique values in each column
# Out:
# id                         569
# diagnosis                    2
# radius_mean                456
# texture_mean               479
# perimeter_mean             522
# area_mean                  539
# smoothness_mean            474
# compactness_mean           537
# concavity_mean             537
# concave points_mean        542
# symmetry_mean              432
# fractal_dimension_mean     499
# radius_se                  540
# texture_se                 519
# perimeter_se               533
# area_se                    528
# smoothness_se              547
# compactness_se             541
# concavity_se               533
# concave points_se          507
# symmetry_se                498
# fractal_dimension_se       545
# radius_worst               457
# texture_worst              511
# perimeter_worst            514
# area_worst                 544
# smoothness_worst           411
# compactness_worst          529
# concavity_worst            539
# concave points_worst       492
# ...

# %%
df.describe()
# this returns useful descriptive statistics for each column of data
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.head(10)
# although, you can specify however many rows you'd like returned
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df.tail(2)
# same thing applies to `.tail()` which returns the last few rows
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 567          0.11780           0.27700          0.3514                0.152
# 568          0.05263           0.04362          0.0000                0.000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 567            0.86810           0.9387                 0.265          0.4087
# 568            0.06444           0.0000                 0.000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# ...

# %% [markdown]
# loc uses labels of rows or columns to select data, while iloc uses the index numbers. We'll use these to index the dataframe below.

# %%
# select all the columns from 'id' to the last mean column
df_means = df.loc[:,'id':'fractal_dimension_mean']
df_means.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean
# ...

# %%
# repeat the step above using index numbers
df_means = df.iloc[:,:12]
df_means.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean
# ...

# %%
df_means.to_csv('cancer_data_means.csv', index=False)
#Let's save the dataframe of means for use in a future notebook.

# %%
df= pd.read_csv('cancer_data_means.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean
# ...

# %% [markdown]
#  If the index expression contains comma separated arrays, then stack them along their first axis. by using np.r_

# %%
import numpy as np
np.r_[np.array([1,2,3]), 0, 0, np.array([4,5,6])]
# Out:
# array([1, 2, 3, 0, 0, 4, 5, 6])

# %%
df['radius_mean'].mean()
# Out:
# 14.127291739894563

# %%
missing = df.columns[df.isnull().any()].tolist()
print(missing)
# Out:
# []

# %%
import numpy as np
np.percentile(df['id'], 75)
# Out:
# 8813129.0

# %%
type(df['diagnosis'][0])
# Out:
# str

# %% [markdown]
# # Clean Data

# %%
dfc = pd.read_csv('Data_clean.csv')
dfc
# Out:
#     Unnamed: 0  user_id  product_id  liked  view_duration  source timestamp  \
# 0            0     3987      997021   True       1.048242     web   18:29.1
# 1            1     6300      865003   True       1.688173     web   20:22.0
# 2            2     6451      712951  False            NaN  mobile   57:50.0
# 3            3     7782      283235   True       0.194162  mobile   48:20.0
# 4            4     7782      283235   True       0.194162  mobile   48:20.0
# 5            5     5700      587019  False       0.493194     web   25:07.0
# 6            6     3400      505123   True            NaN     web   53:21.0
# 7            7     8403      459916  False       0.675041  mobile   54:00.0
# 8            8     8965      943363  False            NaN     web   12:21.1
# 9            9     9693      787546   True       0.101743     web   34:46.0
# 10          10     4107      811855  False       3.112086     web   50:07.0
#
#     Unnamed: 7
# 0          NaN
# 1          NaN
# ...

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     11 non-null     int64
#  1   user_id        11 non-null     int64
#  2   product_id     11 non-null     int64
#  3   liked          11 non-null     bool
#  4   view_duration  8 non-null      float64
#  5   source         11 non-null     object
#  6   timestamp      11 non-null     object
#  7   Unnamed: 7     0 non-null      float64
# dtypes: bool(1), float64(2), int64(3), object(2)
# memory usage: 755.0+ bytes

# %%
mean = dfc['view_duration'].mean()
dfc['view_duration'] = dfc['view_duration'].fillna(mean)
#fill all NaN with the mean value
dfc
# Out:
#     Unnamed: 0  user_id  product_id  liked  view_duration  source timestamp  \
# 0            0     3987      997021   True       1.048242     web   18:29.1
# 1            1     6300      865003   True       1.688173     web   20:22.0
# 2            2     6451      712951  False       0.938350  mobile   57:50.0
# 3            3     7782      283235   True       0.194162  mobile   48:20.0
# 4            4     7782      283235   True       0.194162  mobile   48:20.0
# 5            5     5700      587019  False       0.493194     web   25:07.0
# 6            6     3400      505123   True       0.938350     web   53:21.0
# 7            7     8403      459916  False       0.675041  mobile   54:00.0
# 8            8     8965      943363  False       0.938350     web   12:21.1
# 9            9     9693      787546   True       0.101743     web   34:46.0
# 10          10     4107      811855  False       3.112086     web   50:07.0
#
#     Unnamed: 7
# 0          NaN
# 1          NaN
# ...

# %% [markdown]
# Using fill the Nan with more than one value by putting two bracket in the begin and at the end:
#
# #use means to fill in missing values
# mean = df[['smoothness_max','symmetry_max']].mean()
# df[['smoothness_max','symmetry_max']] = df[['smoothness_max','symmetry_max']].fillna(mean)
# #confirm your correction with info()
# df.info()

# %%
dfc = dfc.drop(columns=['Unnamed: 0', 'Unnamed: 7'])
dfc
# Out:
#     user_id  product_id  liked  view_duration  source timestamp
# 0      3987      997021   True       1.048242     web   18:29.1
# 1      6300      865003   True       1.688173     web   20:22.0
# 2      6451      712951  False       0.938350  mobile   57:50.0
# 3      7782      283235   True       0.194162  mobile   48:20.0
# 4      7782      283235   True       0.194162  mobile   48:20.0
# 5      5700      587019  False       0.493194     web   25:07.0
# 6      3400      505123   True       0.938350     web   53:21.0
# 7      8403      459916  False       0.675041  mobile   54:00.0
# 8      8965      943363  False       0.938350     web   12:21.1
# 9      9693      787546   True       0.101743     web   34:46.0
# 10     4107      811855  False       3.112086     web   50:07.0

# %%
dfc.duplicated()
# The rows that are duplicated
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
dfc.drop_duplicates(inplace=True)
dfc
# Delete the duplicated Rows
# Out:
#     user_id  product_id  liked  view_duration  source timestamp
# 0      3987      997021   True       1.048242     web   18:29.1
# 1      6300      865003   True       1.688173     web   20:22.0
# 2      6451      712951  False       0.938350  mobile   57:50.0
# 3      7782      283235   True       0.194162  mobile   48:20.0
# 5      5700      587019  False       0.493194     web   25:07.0
# 6      3400      505123   True       0.938350     web   53:21.0
# 7      8403      459916  False       0.675041  mobile   54:00.0
# 8      8965      943363  False       0.938350     web   12:21.1
# 9      9693      787546   True       0.101743     web   34:46.0
# 10     4107      811855  False       3.112086     web   50:07.0

# %%
# remove the _mean from column names
new_labels=[]
for col in df.columns:
    if '_mean' in col:
        new_labels.append(col[:-5]) # exclude last 6 characters
    else:
        new_labels.append(col)
new_labels
# Out:
# ['id',
#  'diagnosis',
#  'radius',
#  'texture',
#  'perimeter',
#  'area',
#  'smoothness',
#  'compactness',
#  'concavity',
#  'concave points',
#  'symmetry',
#  'fractal_dimension']

# %%
# assign new labels to columns in dataframe
df.columns = new_labels

# display first few rows of dataframe to confirm changes
df.head()
# Out:
#          id diagnosis  radius  texture  perimeter    area  smoothness  \
# 0    842302         M   17.99    10.38     122.80  1001.0     0.11840
# 1    842517         M   20.57    17.77     132.90  1326.0     0.08474
# 2  84300903         M   19.69    21.25     130.00  1203.0     0.10960
# 3  84348301         M   11.42    20.38      77.58   386.1     0.14250
# 4  84358402         M   20.29    14.34     135.10  1297.0     0.10030
#
#    compactness  concavity  concave points  symmetry  fractal_dimension
# 0      0.27760     0.3001         0.14710    0.2419            0.07871
# 1      0.07864     0.0869         0.07017    0.1812            0.05667
# 2      0.15990     0.1974         0.12790    0.2069            0.05999
# 3      0.28390     0.2414         0.10520    0.2597            0.09744
# 4      0.13280     0.1980         0.10430    0.1809            0.05883

# %%
df.to_csv('cancer_data_means.csv', index=False)
df
# Out:
#            id diagnosis  radius  texture  perimeter    area  smoothness  \
# 0      842302         M   17.99    10.38     122.80  1001.0     0.11840
# 1      842517         M   20.57    17.77     132.90  1326.0     0.08474
# 2    84300903         M   19.69    21.25     130.00  1203.0     0.10960
# 3    84348301         M   11.42    20.38      77.58   386.1     0.14250
# 4    84358402         M   20.29    14.34     135.10  1297.0     0.10030
# ..        ...       ...     ...      ...        ...     ...         ...
# 564    926424         M   21.56    22.39     142.00  1479.0     0.11100
# 565    926682         M   20.13    28.25     131.20  1261.0     0.09780
# 566    926954         M   16.60    28.08     108.30   858.1     0.08455
# 567    927241         M   20.60    29.33     140.10  1265.0     0.11780
# 568     92751         B    7.76    24.54      47.92   181.0     0.05263
#
#      compactness  concavity  concave points  symmetry  fractal_dimension
# ...

# %% [markdown]
# # Exploring Data with Visuals

# %%
import pandas as pd
# %matplotlib inline

dfm= pd.read_csv('salary.csv')
dfm
# Out:
#                                    Job Title               Salary Estimate  \
# 0                             Data Scientist    $53K-$91K (Glassdoor est.)
# 1                  Healthcare Data Scientist   $63K-$112K (Glassdoor est.)
# 2                             Data Scientist    $80K-$90K (Glassdoor est.)
# 3                             Data Scientist    $56K-$97K (Glassdoor est.)
# 4                             Data Scientist   $86K-$143K (Glassdoor est.)
# 5                             Data Scientist   $71K-$119K (Glassdoor est.)
# 6                             Data Scientist    $54K-$93K (Glassdoor est.)
# 7                             Data Scientist   $86K-$142K (Glassdoor est.)
# 8                         Research Scientist    $38K-$84K (Glassdoor est.)
# 9                             Data Scientist  $120K-$160K (Glassdoor est.)
# 10                            Data Scientist  $126K-$201K (Glassdoor est.)
# ...

# %%
dfm.plot(kind='hist');

# %%
dfm.hist(figsize=(12,12));
# plotting distribution for all variable
# explore all data

# %%
#value_counts just put the numbers that in the csv.DONNOT begin from 0
dfm['avg_salary'].value_counts().plot(kind='barh');
# dfm['avg_salary'].value_counts().plot(kind='bar');

# %%
dfm['avg_salary'].value_counts().plot(kind='kde');

# %%
dfm.plot(x='age', y= 'avg_salary',kind='hexbin');

# %%
dfm['Rating'].value_counts().plot(kind='pie',figsize=(8,8));

# %%
dfm['age'].value_counts().plot(kind='hist');

# %%
dfm['age'].plot(kind='hist');
# for hist it is better to not put the value_counts

# %%
pd.plotting.scatter_matrix(dfm, figsize=(12,12));

# %%
dfm.plot(x='age', y= 'avg_salary', kind = 'scatter');

# %%
dfm['age'].plot(kind = 'box');

# %% [markdown]
# # Drawing Conclusions

# %%
import pandas as pd
dff = pd.read_csv('cancer_data_means.csv')
dff
# Out:
#            id diagnosis  radius  texture  perimeter    area  smoothness  \
# 0      842302         M   17.99    10.38     122.80  1001.0     0.11840
# 1      842517         M   20.57    17.77     132.90  1326.0     0.08474
# 2    84300903         M   19.69    21.25     130.00  1203.0     0.10960
# 3    84348301         M   11.42    20.38      77.58   386.1     0.14250
# 4    84358402         M   20.29    14.34     135.10  1297.0     0.10030
# ..        ...       ...     ...      ...        ...     ...         ...
# 564    926424         M   21.56    22.39     142.00  1479.0     0.11100
# 565    926682         M   20.13    28.25     131.20  1261.0     0.09780
# 566    926954         M   16.60    28.08     108.30   858.1     0.08455
# 567    927241         M   20.60    29.33     140.10  1265.0     0.11780
# 568     92751         B    7.76    24.54      47.92   181.0     0.05263
#
#      compactness  concavity  concave points  symmetry  fractal_dimension
# ...

# %%
# just show the variable with M diagnosis
df_m = dff[dff['diagnosis'] == 'M']
df_m
# Out:
#            id diagnosis  radius  texture  perimeter    area  smoothness  \
# 0      842302         M   17.99    10.38     122.80  1001.0     0.11840
# 1      842517         M   20.57    17.77     132.90  1326.0     0.08474
# 2    84300903         M   19.69    21.25     130.00  1203.0     0.10960
# 3    84348301         M   11.42    20.38      77.58   386.1     0.14250
# 4    84358402         M   20.29    14.34     135.10  1297.0     0.10030
# ..        ...       ...     ...      ...        ...     ...         ...
# 563    926125         M   20.92    25.09     143.00  1347.0     0.10990
# 564    926424         M   21.56    22.39     142.00  1479.0     0.11100
# 565    926682         M   20.13    28.25     131.20  1261.0     0.09780
# 566    926954         M   16.60    28.08     108.30   858.1     0.08455
# 567    927241         M   20.60    29.33     140.10  1265.0     0.11780
#
#      compactness  concavity  concave points  symmetry  fractal_dimension
# ...

# %%
df_m['radius'].mean()
# Out:
# 17.46283018867925

# %%
df_m['area'].describe()
# Out:
# count     212.000000
# mean      978.376415
# std       367.937978
# min       361.600000
# 25%       705.300000
# 50%       932.000000
# 75%      1203.750000
# max      2501.000000
# Name: area, dtype: float64

# %%
df_m[df_m['area'] == df_m['area'].min()]
# Out:
#           id diagnosis  radius  texture  perimeter   area  smoothness  \
# 379  9013838         M   11.08    18.83       73.3  361.6      0.1216
#
#      compactness  concavity  concave points  symmetry  fractal_dimension
# 379       0.2154     0.1689         0.06367    0.2196             0.0795

# %%
df_m.tail(10)
# Out:
#            id diagnosis  radius  texture  perimeter    area  smoothness  \
# 521  91762702         M   24.63    21.60     165.50  1841.0     0.10300
# 533  91930402         M   20.47    20.67     134.70  1299.0     0.09156
# 535    919555         M   20.55    20.86     137.80  1308.0     0.10460
# 536  91979701         M   14.27    22.55      93.77   629.8     0.10380
# 562    925622         M   15.22    30.62     103.40   716.9     0.10480
# 563    926125         M   20.92    25.09     143.00  1347.0     0.10990
# 564    926424         M   21.56    22.39     142.00  1479.0     0.11100
# 565    926682         M   20.13    28.25     131.20  1261.0     0.09780
# 566    926954         M   16.60    28.08     108.30   858.1     0.08455
# 567    927241         M   20.60    29.33     140.10  1265.0     0.11780
#
#      compactness  concavity  concave points  symmetry  fractal_dimension
# 521       0.2106    0.23100         0.14710    0.1991            0.06739
# ...

# %%
df_m.iloc[521: , :].sum()
# it suppose to sum all values , but I DONNOT know what wron with it
# Out:
# id                   0.0
# diagnosis            0.0
# radius               0.0
# texture              0.0
# perimeter            0.0
# area                 0.0
# smoothness           0.0
# compactness          0.0
# concavity            0.0
# concave points       0.0
# symmetry             0.0
# fractal_dimension    0.0
# dtype: float64

# %%
df_b = df[df['diagnosis'] == 'B']
df_b['area'].describe()
# Out:
# count    357.000000
# mean     462.790196
# std      134.287118
# min      143.500000
# 25%      378.200000
# 50%      458.400000
# 75%      551.100000
# max      992.100000
# Name: area, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize =(8,6))
ax.hist(df_b['area'], alpha=0.5, label='benign')
ax.hist(df_m['area'], alpha=0.5, label='malignant')
ax.set_title('Distributions of Benign and Malignant Tumor Areas')
ax.set_xlabel('Area')
ax.set_ylabel('Count')
ax.legend(loc='upper right')
plt.show();

# %% [markdown]
# # Communicationg Results

# %%
import pandas as pd

# %matplotlib inline
df_census = pd.read_csv('adult.csv')
df_census.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
import numpy as np
df_census=df_census.replace('?', np.nan)
df_census.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90       NaN   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66       NaN  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                NaN  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                NaN      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
df_a = df_census[df_census['income'] == '>50K']
df_b = df_census[df_census['income'] == '<=50K']

# %%
i = df_a['education'].value_counts().index
# Bcuz each one begin from differente eduction. So we should unite them
df_a['education'].value_counts()[i].plot(kind='bar');

# %%
df_b['education'].value_counts()[i].plot(kind='bar');

# %%
ind = df_a['workclass'].value_counts().index
df_a['workclass'].value_counts()[ind].plot(kind='pie', figsize=(8,8));

# %%
df_a['age'].hist();
df_a['age'].describe()
# Out:
# count    7841.000000
# mean       44.249841
# std        10.519028
# min        19.000000
# 25%        36.000000
# 50%        44.000000
# 75%        51.000000
# max        90.000000
# Name: age, dtype: float64

# %%
df_b['age'].hist();
df_b['age'].describe()
# Out:
# count    24720.000000
# mean        36.783738
# std         14.020088
# min         17.000000
# 25%         25.000000
# 50%         34.000000
# 75%         46.000000
# max         90.000000
# Name: age, dtype: float64

# %% [markdown]
# # Case Study 1

# %% [markdown]
# # Gathering Data

# %%
import pandas as pd
red_df = pd.read_csv('winequality-red.csv', sep=';')
white_df = pd.read_csv('winequality-white.csv', sep=';')
# try to remove sep to know what happen

# %%
red_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
white_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
# # Assessing Data

# %%
# Number of samples & columns of red wine
red_df.shape
# Out:
# (1599, 12)

# %%
# Number of samples & columns of white wine
white_df.shape
# Out:
# (4898, 12)

# %%
# Name of the columns
for i, v in enumerate(red_df.columns):
    print(i, v)
# Out:
# 0 fixed acidity
# 1 volatile acidity
# 2 citric acid
# 3 residual sugar
# 4 chlorides
# 5 free sulfur dioxide
# 6 total sulfur dioxide
# 7 density
# 8 pH
# 9 sulphates
# 10 alcohol
# 11 quality

# %%
# The number of rows that are duplicated
red_df.duplicated().sum()
# Out:
# 240

# %%
white_df.duplicated().sum()
# Out:
# 937

# %%
# The unique values
red_df.nunique()
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
white_df.nunique()
# Out:
# fixed acidity            68
# volatile acidity        125
# citric acid              87
# residual sugar          310
# chlorides               160
# free sulfur dioxide     132
# total sulfur dioxide    251
# density                 890
# pH                      103
# sulphates                79
# alcohol                 103
# quality                   7
# dtype: int64

# %%
# The mean of the density in the red wine
red_df['density'].mean()
# Out:
# 0.9967466791744831

# %% [markdown]
# ### To analyze our data more efficintly let's combine the red and white data set into one data frame

# %% [markdown]
# # Appending Data

# %%
import numpy as np
# Create color columns for each one by numpy lib

# %%
#! Check numpy.reapet in google
# create color array for red dataframe
color_red = np.repeat('red', 1599)

# create color array for white dataframe
color_white = np.repeat('white', 4898)

# %%
red_df['color'] = color_red
red_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
white_df['color'] = color_white
white_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6  white
# 1      9.5        6  white
# ...

# %% [markdown]
# ### Compine Data Frame with append (Check Pandas concat)

# %%
# append dataframes
wine_df = pd.concat([red_df, white_df])
# ! You can merge more than to flie also by concat
# view dataframe to check for success
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# Save combined dataset
wine_df.to_csv('winequality_edited.csv', index=False)

# %% [markdown]
# In order to rename method: df=df.rename(columns = {'old_name' : 'new_name'})

# %% [markdown]
# # Exploring with Visuals

# %% [markdown]
# ### Histograms for Various Features

# %%
wine_df['fixed acidity'].hist();

# %%
wine_df['total sulfur dioxide'].hist();

# %%
wine_df['pH'].hist();

# %%
wine_df['alcohol'].hist();

# %% [markdown]
# Based on histograms of the upper columns. The variables that appears skewed to the right are (Fixed Acidity & Alcohol)

# %% [markdown]
# ### Scatterplots of Quality Against Various Features

# %%
wine_df.plot(x="volatile acidity", y="quality", kind="scatter");

# %%
wine_df.plot(x="residual sugar", y="quality", kind="scatter");

# %%
wine_df.plot(x="pH", y="quality", kind="scatter");

# %%
wine_df.plot(x="alcohol", y="quality", kind="scatter");

# %% [markdown]
# Based on scatterplots of quality against different feature variables. The most likely to have a positive impact on quality is (Alcohol)

# %% [markdown]
# GROUPBY lets you group your data by a specific column(s) and creates aggregate information about those groupings. It also allows for group-specific transformations. In this section, we will use groupby to get summary statistics about different groups in our data.

# %%
wine_df.mean()
# Out:
# C:\Users\Tsgts\AppData\Local\Temp\ipykernel_46056\1051026738.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   wine_df.mean()
# fixed acidity             7.215307
# volatile acidity          0.339666
# citric acid               0.318633
# residual sugar            5.443235
# chlorides                 0.056034
# free sulfur dioxide      30.525319
# total sulfur dioxide    115.744574
# density                   0.994697
# pH                        3.218501
# sulphates                 0.531268
# alcohol                  10.491801
# quality                   5.818378
# dtype: float64

# %%
wine_df.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             7.853333          0.517000     0.281000        5.140000
# 4             7.288889          0.457963     0.272315        4.153704
# 5             7.326801          0.389614     0.307722        5.804116
# 6             7.177257          0.313863     0.323583        5.549753
# 7             7.128962          0.288800     0.334764        4.731696
# 8             6.835233          0.291010     0.332539        5.382902
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.077033            39.216667            122.033333  0.995744
# 4         0.060056            20.636574            103.432870  0.994833
# 5         0.064666            30.237371            120.839102  0.995849
# 6         0.054157            31.165021            115.410790  0.994558
# ...

# %%
wine_df.groupby(['quality', 'color'], as_index=False)['pH'].mean()
# Out:
#     quality  color        pH
# 0         3    red  3.398000
# 1         3  white  3.187500
# 2         4    red  3.381509
# 3         4  white  3.182883
# 4         5    red  3.304949
# 5         5  white  3.168833
# 6         6    red  3.318072
# 7         6  white  3.188599
# 8         7    red  3.290754
# 9         7  white  3.213898
# 10        8    red  3.267222
# 11        8  white  3.218686
# 12        9  white  3.308000

# %% [markdown]
# Q1: Is a certain type of wine (red or white) associated with higher quality?

# %%
wine_df.groupby(['color'], as_index= False)['quality'].mean()
# Out:
#    color   quality
# 0    red  5.636023
# 1  white  5.877909

# %% [markdown]
# Q2: What level of acidity (pH value) receives the highest average rating?

# %%
# View the min, 25%, 50%, 75%, max pH values with Pandas describe
wine_df['pH'].describe()
# Out:
# count    6497.000000
# mean        3.218501
# std         0.160787
# min         2.720000
# 25%         3.110000
# 50%         3.210000
# 75%         3.320000
# max         4.010000
# Name: pH, dtype: float64

# %% [markdown]
# ## Pandas Cut

# %%
# Bin edges that will be used to "cut" the data into groups
bin_edges = [2.72, 3.11, 3.21, 3.32, 4.01] # Fill in this list with five values you just found

# %%
# Labels for the four acidity level groups
bin_names = ['high', 'mod_high', 'medium', 'low'] # Name each acidity level category

# %%
# Creates acidity_levels column
wine_df['acidity_levels'] = pd.cut(wine_df['pH'], bin_edges, labels=bin_names)

# Checks for successful creation of this column
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color acidity_levels
# 0      9.4        5   red            low
# ...

# %%
wine_df.groupby(['acidity_levels'], as_index= False)['quality'].mean()
# Out:
#   acidity_levels   quality
# 0           high  5.783343
# 1       mod_high  5.784540
# 2         medium  5.850832
# 3            low  5.859593

# %%
wine_df.to_csv('winequality_edited.csv', index=False)

# %% [markdown]
# ## Pandas Query

# %% [markdown]
# #selecting records of people making over $50K
# df_a = df[df['income'] == ' >50K']
# df_a = df.query('income == " >50K"')
# # selecting records in cancer data with radius greater than the median
# df_h = df[df['radius'] > 13.375]
# df_h = df.query('radius > 13.375')

# %% [markdown]
# Q1: Do wines with higher alcoholic content receive better ratings?

# %%
# Low alcohol (samples with an alcohol content less than the median)
# High alcohol (samples with an alcohol content greater than or equal to the median)
wine_df['alcohol'].median()
# Out:
# 10.3

# %%
low_alcohol = wine_df.query('alcohol < 10.3')
high_alcohol = wine_df.query('alcohol >= 10.3')
# ensure these queries included each sample exactly once
num_samples = df.shape[0]
num_samples == low_alcohol['quality'].count() + high_alcohol['quality'].count() # should be True
# Out:
# False

# %%
# get mean quality rating for the low alcohol and high alcohol groups
low_alcohol['quality'].mean(),high_alcohol['quality'].mean()
# Out:
# (5.475920679886686, 6.146084337349397)

# %% [markdown]
# Q2: Do sweeter wines (more residual sugar) receive better ratings?

# %%
wine_df['residual sugar'].median()
# Out:
# 3.0

# %%
low_sweet = wine_df.query('`residual sugar` < 3')
high_sweet = wine_df.query('`residual sugar` >= 3')
# In the query string, you need to enclose the column name 'residual sugar' within backticks (`) because it contains a space.

# %%
low_sweet['quality'].mean(), high_sweet['quality'].mean()
# Out:
# (5.808800743724822, 5.82782874617737)

# %% [markdown]
# # Draw Conclusions

# %% [markdown]
# ## Type & Quality Plot - PART 1

# %% [markdown]
# Now that we've made some conclusions, we can create visualizations to display our findings regarding the association between wine quality and different properties of wine.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
colors=['red','grey']
color_means = wine_df.groupby('color')['quality'].mean() 
color_means.plot(kind = 'bar', title='average Wine Quality by Color', color = colors, alpha = .7);
plt.xlabel('Colors')
plt.ylabel('Quality')
# Out:
# Text(0, 0.5, 'Quality')

# %%
counts = wine_df.groupby(['quality', 'color']).count()
counts
# Out:
#                fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality color
# 3       red               10                10           10              10
#         white             20                20           20              20
# 4       red               53                53           53              53
#         white            163               163          163             163
# 5       red              681               681          681             681
#         white           1457              1457         1457            1457
# 6       red              638               638          638             638
#         white           2198              2198         2198            2198
# 7       red              199               199          199             199
#         white            880               880          880             880
# 8       red               18                18           18              18
# ...

# %%
counts = wine_df.groupby(['quality', 'color']).count()['pH']
colors = ['red', 'grey']
counts.plot(kind='bar', title='Counts by Wine Color and Quality', color=colors, alpha=.7);
plt.xlabel('Quality and Color', fontsize=18)
plt.ylabel('Count', fontsize=18)
# Out:
# Text(0, 0.5, 'Count')

# %%
totals = wine_df.groupby('color').count()['pH']
proportions = counts / totals
proportions.plot(kind='bar', title='Proportion by Wine Color and Quality', color=colors, alpha=.7);
plt.xlabel('Quality and Color', fontsize=18)
plt.ylabel('Proportion', fontsize=18)
# Out:
# Text(0, 0.5, 'Proportion')

# %% [markdown]
# ### Creating a Bar Chart Using Matplotlib

# %%
plt.bar([1, 2, 3], [224, 620, 425], tick_label=['a', 'b', 'c'])
plt.title('Some Title')
plt.xlabel('Some X Label')
plt.ylabel('Some Y Label');
# EX.

# %% [markdown]
# ### Plotting with Matplotlib

# %% [markdown]
# ### 1: Do wines with higher alcoholic content receive better ratings?

# %%
# Use query to select each group and get its mean quality
median = wine_df['alcohol'].median()
low = wine_df.query('alcohol < {}'.format(median))
high = wine_df.query('alcohol >= {}'.format(median))

mean_quality_low = low['quality'].mean()
mean_quality_high = high['quality'].mean()

# %%
# Create a bar chart with proper labels
locations = [1, 2]
heights = [mean_quality_low, mean_quality_high]
labels = ['Low', 'High']
plt.bar(locations, heights, tick_label=labels)
plt.title('Average Quality Ratings by Alcohol Content')
plt.xlabel('Alcohol Content')
plt.ylabel('Average Quality Rating');

# %% [markdown]
# ### 2: Do sweeter wines receive higher ratings?

# %%
# Use query to select each group and get its mean quality
median = wine_df['residual sugar'].median()
low = wine_df.query('`residual sugar` < {}'.format(median))
high = wine_df.query("`residual sugar` >= {}".format(median))

low_sweet = low['quality'].mean()
high_sweet = high['quality'].mean()

# %%
# Create a bar chart with proper labels
location = [1,2]
hight = [low_sweet, high_sweet]
labels = ['Low', 'High']
plt.bar(location, hight, tick_label = labels)
plt.title('The Higher Rate of Sweet for Wine')
plt.xlabel('Residual Sugar Content')
plt.ylabel('Average Sweet Rating')
# Out:
# Text(0, 0.5, 'Average Sweet Rating')

# %% [markdown]
# ### 3: What level of acidity receives the highest average rating?

# %%
# Use groupby to get the mean quality for each acidity level
mean_levels=wine_df.groupby(['acidity_levels'])['quality'].mean()
mean_levels
# Out:
# acidity_levels
# high        5.783343
# mod_high    5.784540
# medium      5.850832
# low         5.859593
# Name: quality, dtype: float64

# %%
# Create a bar chart with proper labels
locations = [1, 2, 3, 4]  # reorder values above to go from low to high
heights = mean_levels

# labels = ['Low', 'Medium', 'Moderately High', 'High']
labels = mean_levels.index.str.replace('_', ' ').str.title() # alternative to commented out line above

plt.bar(locations, heights, tick_label=labels)
plt.title('Average Quality Ratings by Acidity Level')
plt.xlabel('Acidity Level')
plt.ylabel('Average Quality Rating');

# %% [markdown]
# ## Plotting Wine Type & Quality with Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

wine_df = pd.read_csv('winequality_edited.csv')

# %% [markdown]
# ### Create arrays for red bar heights white bar heights
#
# Remember, there's a bar for each combination of color and quality rating. Each bar's height is based on the proportion of samples of that color with that quality rating.
#
#  Red bar proportions = counts for each quality rating / total # of red samples
#
#  White bar proportions = counts for each quality rating / total # of white samples

# %%
# get counts for each rating and color
color_counts = wine_df.groupby(['color', 'quality']).count()['pH']
color_counts
# Out:
# color  quality
# red    3            10
#        4            53
#        5           681
#        6           638
#        7           199
#        8            18
# white  3            20
#        4           163
#        5          1457
#        6          2198
#        7           880
#        8           175
#        9             5
# Name: pH, dtype: int64

# %%
# get total counts for each color
color_totals = wine_df.groupby('color').count()['pH']
color_totals
# Out:
# color
# red      1599
# white    4898
# Name: pH, dtype: int64

# %%
# get proportions by dividing red rating counts by total # of red samples
red_proportions = color_counts['red'] / color_totals['red']
red_proportions['9'] = 0 # The number should be equal to the white
red_proportions
# Out:
# quality
# 3    0.006254
# 4    0.033146
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 8    0.011257
# 9    0.000000
# Name: pH, dtype: float64

# %%
# get proportions by dividing white rating counts by total # of white samples
white_proportions = color_counts['white'] / color_totals['white']
white_proportions
# Out:
# quality
# 3    0.004083
# 4    0.033279
# 5    0.297468
# 6    0.448755
# 7    0.179665
# 8    0.035729
# 9    0.001021
# Name: pH, dtype: float64

# %% [markdown]
# ### Plot proportions on a bar chart
#
# Set the x coordinate location for each rating group and and width of each bar.

# %%
ind = np.arange(len(red_proportions))  # the x locations for the groups
width = 0.35       # the width of the bars

# %%
# plot bars
red_bars = plt.bar(ind, red_proportions, width, color='r', alpha=.7, label='Red Wine')
white_bars = plt.bar(ind + width, white_proportions, width, color='w', alpha=.7, label='White Wine')

# title and labels
plt.ylabel('Proportion')
plt.xlabel('Quality')
plt.title('Proportion by Wine Color and Quality')
locations = ind + width / 2  # xtick locations
labels = ['3', '4', '5', '6', '7', '8', '9']  # xtick labels
plt.xticks(locations, labels)

# legend: try to delete it
plt.legend()

# %% [markdown]
# # Case Study 2

# %% [markdown]
# # Assessing Data

# %%
import pandas as pd
df8 = pd.read_csv('all_alpha_08.csv')
df18 = pd.read_csv('all_alpha_18.csv')

# %%
df8.head()
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
#
#    Underhood ID    Veh Class Air Pollution Score FE Calc Appr City MPG  \
# 0  8HNXT03.7PKR          SUV                   7          Drv       15
# 1  8HNXT03.7PKR          SUV                   6          Drv       15
# 2  8HNXT02.3DKR          SUV                   7          Drv       17
# 3  8HNXT02.3DKR          SUV                   6          Drv       17
# 4  8HNXV03.5HKR  midsize car                   7          Drv       16
#
#   Hwy MPG Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# ...

# %%
df18.head()
# Out:
#        Model  Displ  Cyl       Trans Drive      Fuel Cert Region       Stnd  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA     T3B125
# 1  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA         U2
# 2  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          FA     T3B125
# 3  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA         U2
# 4  ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA  L3ULEV125
#
#              Stnd Description  Underhood ID  Veh Class  Air Pollution Score  \
# 0      Federal Tier 3 Bin 125  JHNXT03.5GV3  small SUV                    3
# 1      California LEV-II ULEV  JHNXT03.5GV3  small SUV                    3
# 2      Federal Tier 3 Bin 125  JHNXT03.5GV3  small SUV                    3
# 3      California LEV-II ULEV  JHNXT03.5GV3  small SUV                    3
# 4  California LEV-III ULEV125  JHNXV02.4WH3  small car                    3
#
# ...

# %%
for i,v in enumerate(df8.columns):
    print(i+1, v)
# Out:
# 1 Model
# 2 Displ
# 3 Cyl
# 4 Trans
# 5 Drive
# 6 Fuel
# 7 Sales Area
# 8 Stnd
# 9 Underhood ID
# 10 Veh Class
# 11 Air Pollution Score
# 12 FE Calc Appr
# 13 City MPG
# 14 Hwy MPG
# 15 Cmb MPG
# 16 Unadj Cmb MPG
# 17 Greenhouse Gas Score
# 18 SmartWay

# %%
for i,v in enumerate(df18.columns):
    print(i+1, v)
# Out:
# 1 Model
# 2 Displ
# 3 Cyl
# 4 Trans
# 5 Drive
# 6 Fuel
# 7 Cert Region
# 8 Stnd
# 9 Stnd Description
# 10 Underhood ID
# 11 Veh Class
# 12 Air Pollution Score
# 13 City MPG
# 14 Hwy MPG
# 15 Cmb MPG
# 16 Greenhouse Gas Score
# 17 SmartWay
# 18 Comb CO2

# %%
df8.shape, df18.shape
# Out:
# ((2404, 18), (1611, 18))

# %%
df8.duplicated().sum(), df18.duplicated().sum()
# Out:
# (25, 0)

# %%
df8.isnull().sum(), df18.isnull().sum()
# Out:
# (Model                     0
#  Displ                     0
#  Cyl                     199
#  Trans                   199
#  Drive                    93
#  Fuel                      0
#  Sales Area                0
#  Stnd                      0
#  Underhood ID              0
#  Veh Class                 0
#  Air Pollution Score       0
#  FE Calc Appr            199
#  City MPG                199
#  Hwy MPG                 199
#  Cmb MPG                 199
#  Unadj Cmb MPG           199
#  Greenhouse Gas Score    199
#  SmartWay                  0
#  dtype: int64,
#  Model                   0
#  Displ                   2
#  Cyl                     2
#  Trans                   0
#  Drive                   0
#  Fuel                    0
#  Cert Region             0
#  Stnd                    0
#  Stnd Description        0
#  Underhood ID            0
#  Veh Class               0
#  Air Pollution Score     0
#  City MPG                0
#  Hwy MPG                 0
# ...

# %%
df18['Cyl'].dtype
# Out:
# dtype('float64')

# %%
df8.nunique().sum(), df18.nunique().sum()
# Out:
# (1757, 1217)

# %%
df8.nunique(), df18.nunique()
# Out:
# (Model                   436
#  Displ                    47
#  Cyl                       8
#  Trans                    14
#  Drive                     2
#  Fuel                      5
#  Sales Area                3
#  Stnd                     12
#  Underhood ID            343
#  Veh Class                 9
#  Air Pollution Score      13
#  FE Calc Appr              2
#  City MPG                 39
#  Hwy MPG                  43
#  Cmb MPG                  38
#  Unadj Cmb MPG           721
#  Greenhouse Gas Score     20
#  SmartWay                  2
#  dtype: int64,
#  Model                   367
#  Displ                    36
#  Cyl                       7
#  Trans                    26
#  Drive                     2
#  Fuel                      5
#  Cert Region               2
#  Stnd                     19
#  Stnd Description         19
#  Underhood ID            230
#  Veh Class                 9
#  Air Pollution Score       6
#  City MPG                 58
# ...

# %%
df8['Fuel'].unique()
# Out:
# array(['Gasoline', 'ethanol/gas', 'ethanol', 'diesel', 'CNG'],
#       dtype=object)

# %%
df18['Fuel'].unique()
# Out:
# array(['Gasoline', 'Gasoline/Electricity', 'Diesel', 'Ethanol/Gas',
#        'Electricity'], dtype=object)

# %% [markdown]
# # Cleaning Column Labels

# %% [markdown]
# 1- Drop extraneous columns
# Drop features that aren't consistent (not present in both datasets) or aren't relevant to our questions. Use pandas' drop function.
# Columns to Drop:
#
#     From 2008 dataset: 'Stnd', 'Underhood ID', 'FE Calc Appr', 'Unadj Cmb MPG'
#     From 2018 dataset: 'Stnd', 'Stnd Description', 'Underhood ID', 'Comb CO2'

# %%
df8.drop(['Stnd', 'Underhood ID', 'FE Calc Appr', 'Unadj Cmb MPG'] ,axis=1, inplace=True)
# axis = 1 REFERS to COLUMNS , axis = 0 REFERS to ROW
# 
df8.head(0)
# Out:
# Empty DataFrame
# Columns: [Model, Displ, Cyl, Trans, Drive, Fuel, Sales Area, Veh Class, Air Pollution Score, City MPG, Hwy MPG, Cmb MPG, Greenhouse Gas Score, SmartWay]
# Index: []

# %%
df18.drop(['Stnd', 'Stnd Description', 'Underhood ID', 'Comb CO2'] ,axis=1, inplace=True)
df18.head(0)
# Out:
# Empty DataFrame
# Columns: [Model, Displ, Cyl, Trans, Drive, Fuel, Cert Region, Veh Class, Air Pollution Score, City MPG, Hwy MPG, Cmb MPG, Greenhouse Gas Score, SmartWay]
# Index: []

# %% [markdown]
# 2. Rename Columns
#
#     Change the "Sales Area" column label in the 2008 dataset to "Cert Region" for consistency.
#     Rename all column labels to replace spaces with underscores and convert everything to lowercase. (Underscores can be much easier to work with in Python than spaces. For example, having spaces wouldn't allow you to use df.column_name instead of df['column_name'] to select columns or use query(). Being consistent with lowercase and underscores also helps make column names easy to remember.)

# %%
df8 = df8.rename(columns = {'Sales Area' : 'Cert Region'})
df8.head(0)
# Out:
# Empty DataFrame
# Columns: [Model, Displ, Cyl, Trans, Drive, Fuel, Cert Region, Veh Class, Air Pollution Score, City MPG, Hwy MPG, Cmb MPG, Greenhouse Gas Score, SmartWay]
# Index: []

# %%
# replace spaces with underscores and lowercase labels for 2008 dataset
df8.rename(columns=lambda x: x.strip().lower().replace(" ", "_"), inplace=True)
# confirm changes
df8.head(0)
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, cert_region, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %% [markdown]
# 1-Here, a lambda function is used as the mapping to rename the columns. The lambda function takes each column name (x) as input and performs the following operations on it:

# %% [markdown]
# 2-.strip(): This removes any leading or trailing whitespace from the column name. For example, if a column name has spaces before or after it, this operation eliminates those spaces.

# %% [markdown]
# 3- inplace=True: This parameter specifies whether to modify the DataFrame in place or return a new DataFrame with the modified column names. When inplace=True, the original DataFrame is modified. If inplace=False or omitted, a new DataFrame with the updated column names is returned, leaving the original DataFrame unchanged.

# %%
df18.rename(columns = lambda x:x.strip().lower().replace(" ", "_"), inplace = True)
df18.head(0)
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, cert_region, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
# confirm column labels for 2008 and 2018 datasets are identical
df8.columns == df18.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
# make sure they're all identical like this
(df8.columns == df18.columns).all()
# Out:
# True

# %%
# save new datasets for next section
df8.to_csv('data_08_v1.csv', index=False)
df18.to_csv('data_18_v1.csv', index=False)

# %% [markdown]
# # Filter, Drop Nulls, Dedups

# %% [markdown]
# 1. Filter
#
# For consistency, only compare cars certified by California standards. Filter both datasets using query to select only rows where cert_region is CA. Then, drop the cert_region columns, since it will no longer provide any useful information (we'll know every value is 'CA').

# %%
df8.shape, df18.shape
# Out:
# ((2404, 14), (1611, 14))

# %%
df8=df8.query('cert_region == "CA"')
df8.head()
# Out:
#        model  displ      cyl    trans drive      fuel cert_region  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          CA
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 6   ACURA TL    3.2  (6 cyl)  Auto-S5   2WD  Gasoline          CA
# 7   ACURA TL    3.5  (6 cyl)  Auto-S5   2WD  Gasoline          CA
#
#      veh_class air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 0          SUV                   7       15      20      17
# 2          SUV                   7       17      22      19
# 4  midsize car                   7       16      24      19
# 6  midsize car                   7       18      26      21
# 7  midsize car                   7       17      26      20
#
#   greenhouse_gas_score smartway
# 0                    4       no
# 2                    5       no
# 4                    5       no
# 6                    6      yes
# 7                    6      yes

# %%
df18=df18.query('cert_region == "CA"')
df18.head()
# Remember that Query delete all the rows except the one you choose
# Out:
#        model  displ  cyl       trans drive      fuel cert_region  veh_class  \
# 1  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA  small SUV
# 3  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA  small SUV
# 4  ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA  small car
# 6  ACURA TLX    3.5  6.0  SemiAuto-9   2WD  Gasoline          CA  small car
# 8  ACURA TLX    3.5  6.0  SemiAuto-9   4WD  Gasoline          CA  small car
#
#    air_pollution_score city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score smartway
# 1                    3       20      28      23                     5       No
# 3                    3       19      27      22                     4       No
# 4                    3       23      33      27                     6       No
# 6                    3       20      32      24                     5       No
# 8                    3       21      30      24                     5       No

# %%
df8['cert_region'].unique()
# Out:
# array(['CA'], dtype=object)

# %%
# df8.drop(columns=['cert_region'],axis=1, inplace = True)
df8.drop('cert_region',axis=1, inplace = True)
df18.drop('cert_region',axis=1, inplace = True)

# %%
df8.shape, df18.shape
# Out:
# ((1084, 13), (798, 13))

# %% [markdown]
# 2. Drop Nulls
#
# Drop any rows in both datasets that contain missing values.

# %%
df8.dropna(inplace=True)
df8.head()
# Out:
#        model  displ      cyl    trans drive      fuel    veh_class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          SUV
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          SUV
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline  midsize car
# 6   ACURA TL    3.2  (6 cyl)  Auto-S5   2WD  Gasoline  midsize car
# 7   ACURA TL    3.5  (6 cyl)  Auto-S5   2WD  Gasoline  midsize car
#
#   air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 0                   7       15      20      17                    4       no
# 2                   7       17      22      19                    5       no
# 4                   7       16      24      19                    5       no
# 6                   7       18      26      21                    6      yes
# 7                   7       17      26      20                    6      yes

# %%
df18.dropna(inplace=True)
df18.head()
# Out:
#        model  displ  cyl       trans drive      fuel  veh_class  \
# 1  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline  small SUV
# 3  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline  small SUV
# 4  ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline  small car
# 6  ACURA TLX    3.5  6.0  SemiAuto-9   2WD  Gasoline  small car
# 8  ACURA TLX    3.5  6.0  SemiAuto-9   4WD  Gasoline  small car
#
#    air_pollution_score city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score smartway
# 1                    3       20      28      23                     5       No
# 3                    3       19      27      22                     4       No
# 4                    3       23      33      27                     6       No
# 6                    3       20      32      24                     5       No
# 8                    3       21      30      24                     5       No

# %%
df8.isnull().sum().any(), df18.isnull().sum().any()
# Out:
# (False, False)

# %% [markdown]
# 3. Dedupe
#
# Drop any duplicate rows in both datasets.

# %%
df8.duplicated().sum(), df18.duplicated().sum()
# Out:
# (23, 3)

# %%
# To know more about any Function
help(pd.DataFrame.drop)
# Out:
# Help on function drop in module pandas.core.frame:
#
# drop(self, labels=None, axis: 'Axis' = 0, index=None, columns=None, level: 'Level | None' = None, inplace: 'bool' = False, errors: 'str' = 'raise')
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by specifying directly index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level. See the `user guide <advanced.shown_levels>`
#     for more information about the now unused levels.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop. A tuple will be used as a single
#         label and not treated as a list-like.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Whether to drop labels from the index (0 or 'index') or
#         columns (1 or 'columns').
#     index : single label or list-like
# ...

# %%
df8 = df8.drop_duplicates()
df8.duplicated().sum()
# Out:
# 0

# %%
df18 = df18.drop_duplicates()
df18.duplicated().sum()
# Out:
# 0

# %%
# save progress for the next section
df8.to_csv('data_08_v2.csv', index=False)
df18.to_csv('data_18_v2.csv', index=False)

# %%
df8.shape, df18.shape
# Out:
# ((986, 13), (794, 13))

# %% [markdown]
# # Inspecting Data Types

# %%
df8
# Out:
#             model  displ      cyl    trans drive      fuel      veh_class  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline            SUV
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline            SUV
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline    midsize car
# 6        ACURA TL    3.2  (6 cyl)  Auto-S5   2WD  Gasoline    midsize car
# 7        ACURA TL    3.5  (6 cyl)  Auto-S5   2WD  Gasoline    midsize car
# ...           ...    ...      ...      ...   ...       ...            ...
# 2394    VOLVO V70    3.2  (6 cyl)  Auto-S6   2WD  Gasoline  station wagon
# 2396  VOLVO XC 70    3.2  (6 cyl)  Auto-S6   4WD  Gasoline            SUV
# 2398  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline            SUV
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline            SUV
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline            SUV
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# ...

# %%
df18
# Out:
#             model  displ  cyl       trans drive                  fuel  \
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD              Gasoline
# 6       ACURA TLX    3.5  6.0  SemiAuto-9   2WD              Gasoline
# 8       ACURA TLX    3.5  6.0  SemiAuto-9   4WD              Gasoline
# ...           ...    ...  ...         ...   ...                   ...
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1603  VOLVO XC 90    2.0  4.0  SemiAuto-8   2WD              Gasoline
# 1605  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#          veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# ...

# %%
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 794 entries, 1 to 1609
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 794 non-null    object
#  1   displ                 794 non-null    float64
#  2   cyl                   794 non-null    float64
#  3   trans                 794 non-null    object
#  4   drive                 794 non-null    object
#  5   fuel                  794 non-null    object
#  6   veh_class             794 non-null    object
#  7   air_pollution_score   794 non-null    int64
#  8   city_mpg              794 non-null    object
#  9   hwy_mpg               794 non-null    object
#  10  cmb_mpg               794 non-null    object
#  11  greenhouse_gas_score  794 non-null    int64
#  12  smartway              794 non-null    object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 86.8+ KB

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 986 entries, 0 to 2400
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 986 non-null    object
#  1   displ                 986 non-null    float64
#  2   cyl                   986 non-null    object
#  3   trans                 986 non-null    object
#  4   drive                 986 non-null    object
#  5   fuel                  986 non-null    object
#  6   veh_class             986 non-null    object
#  7   air_pollution_score   986 non-null    object
#  8   city_mpg              986 non-null    object
#  9   hwy_mpg               986 non-null    object
#  10  cmb_mpg               986 non-null    object
#  11  greenhouse_gas_score  986 non-null    object
#  12  smartway              986 non-null    object
# dtypes: float64(1), object(12)
# memory usage: 107.8+ KB

# %% [markdown]
# Quiz Question
#
# Which of the following changes could be made to make the cyl column in both datasets clear and consistent?
#
# 1)Extract int Values from the String in the 2008 cyl columns..
# 2)Convert Floats to Ints in the 2018 cyl columns

# %% [markdown]
# Quiz Question
#
# Which of the following changes could be made to make the air_pollution_score column in both datasets consistent?
#
# 1)Convert String to Floats in the 2008 columns..
# 2)Convert Ints to Floats in the 2018 columns

# %% [markdown]
# Quiz Question
#
# Which changes need to be made to make the greenhouse_gas_score columns in both datasets consistent?
#
# 1) Convert String ti Ints in 2008 columns

# %%
# Let's now fix these ERROR (;

# %% [markdown]
# # Fixing Data Types Pt 1

# %% [markdown]
# Fix cyl datatype
#
#     2008: extract int from string.
#     2018: convert float to int.

# %%
# check value counts for the 2008 cyl column
df8['cyl'].value_counts()
# Out:
# (6 cyl)     409
# (4 cyl)     283
# (8 cyl)     199
# (5 cyl)      48
# (12 cyl)     30
# (10 cyl)     14
# (2 cyl)       2
# (16 cyl)      1
# Name: cyl, dtype: int64

# %%
# Extract int from strings in the 2008 cyl column
df8['cyl'] = df8['cyl'].str.extract('(\d+)').astype(int)
df8.head()
# Out:
#        model  displ  cyl    trans drive      fuel    veh_class  \
# 0  ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline          SUV
# 2  ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline          SUV
# 4   ACURA RL    3.5    6  Auto-S5   4WD  Gasoline  midsize car
# 6   ACURA TL    3.2    6  Auto-S5   2WD  Gasoline  midsize car
# 7   ACURA TL    3.5    6  Auto-S5   2WD  Gasoline  midsize car
#
#   air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 0                   7       15      20      17                    4       no
# 2                   7       17      22      19                    5       no
# 4                   7       16      24      19                    5       no
# 6                   7       18      26      21                    6      yes
# 7                   7       17      26      20                    6      yes

# %%
# Check value counts for 2008 cyl column again to confirm the change
df8['cyl'].value_counts()
# Out:
# 6     409
# 4     283
# 8     199
# 5      48
# 12     30
# 10     14
# 2       2
# 16      1
# Name: cyl, dtype: int64

# %%
# Change float to int
df18['cyl'] = df18['cyl'].astype(int)
df18.head()
# Out:
#        model  displ  cyl       trans drive      fuel  veh_class  \
# 1  ACURA RDX    3.5    6  SemiAuto-6   2WD  Gasoline  small SUV
# 3  ACURA RDX    3.5    6  SemiAuto-6   4WD  Gasoline  small SUV
# 4  ACURA TLX    2.4    4       AMS-8   2WD  Gasoline  small car
# 6  ACURA TLX    3.5    6  SemiAuto-9   2WD  Gasoline  small car
# 8  ACURA TLX    3.5    6  SemiAuto-9   4WD  Gasoline  small car
#
#    air_pollution_score city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score smartway
# 1                    3       20      28      23                     5       No
# 3                    3       19      27      22                     4       No
# 4                    3       23      33      27                     6       No
# 6                    3       20      32      24                     5       No
# 8                    3       21      30      24                     5       No

# %% [markdown]
# Fix air_pollution_score datatype
#
#     2008: convert string to float.
#     2018: convert int to float.

# %%
# Change String to Float
df8['air_pollution_score'] = df8['air_pollution_score'].str.extract('(\d+)').astype(float)
df8.head()
# Out:
#        model  displ  cyl    trans drive      fuel    veh_class  \
# 0  ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline          SUV
# 2  ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline          SUV
# 4   ACURA RL    3.5    6  Auto-S5   4WD  Gasoline  midsize car
# 6   ACURA TL    3.2    6  Auto-S5   2WD  Gasoline  midsize car
# 7   ACURA TL    3.5    6  Auto-S5   2WD  Gasoline  midsize car
#
#    air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 0                  7.0       15      20      17                    4       no
# 2                  7.0       17      22      19                    5       no
# 4                  7.0       16      24      19                    5       no
# 6                  7.0       18      26      21                    6      yes
# 7                  7.0       17      26      20                    6      yes

# %%
df18['air_pollution_score'] = df18['air_pollution_score'].astype(float)
df18.head()
# Out:
#        model  displ  cyl       trans drive      fuel  veh_class  \
# 1  ACURA RDX    3.5    6  SemiAuto-6   2WD  Gasoline  small SUV
# 3  ACURA RDX    3.5    6  SemiAuto-6   4WD  Gasoline  small SUV
# 4  ACURA TLX    2.4    4       AMS-8   2WD  Gasoline  small car
# 6  ACURA TLX    3.5    6  SemiAuto-9   2WD  Gasoline  small car
# 8  ACURA TLX    3.5    6  SemiAuto-9   4WD  Gasoline  small car
#
#    air_pollution_score city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score smartway
# 1                  3.0       20      28      23                     5       No
# 3                  3.0       19      27      22                     4       No
# 4                  3.0       23      33      27                     6       No
# 6                  3.0       20      32      24                     5       No
# 8                  3.0       21      30      24                     5       No

# %% [markdown]
# Fix city_mpg, hwy_mpg, cmb_mpg datatypes
#
#     2008 and 2018: convert string to float.

# %%
import re
df8[['city_mpg', 'hwy_mpg', 'cmb_mpg']] = df8[['city_mpg', 'hwy_mpg', 'cmb_mpg']].apply(lambda x: x.str.extract(r'(\d+)', expand=False).astype(float))
df8.head() 
# expression pattern r'(\d+)' to extract one or more digits
# expand=False argument ensures that a Series is returned instead of a DataFrame
# ALWAYS use lambda if you are working with more than one column
# Out:
#        model  displ  cyl    trans drive      fuel    veh_class  \
# 0  ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline          SUV
# 2  ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline          SUV
# 4   ACURA RL    3.5    6  Auto-S5   4WD  Gasoline  midsize car
# 6   ACURA TL    3.2    6  Auto-S5   2WD  Gasoline  midsize car
# 7   ACURA TL    3.5    6  Auto-S5   2WD  Gasoline  midsize car
#
#    air_pollution_score  city_mpg  hwy_mpg  cmb_mpg greenhouse_gas_score  \
# 0                  7.0      15.0     20.0     17.0                    4
# 2                  7.0      17.0     22.0     19.0                    5
# 4                  7.0      16.0     24.0     19.0                    5
# 6                  7.0      18.0     26.0     21.0                    6
# 7                  7.0      17.0     26.0     20.0                    6
#
#   smartway
# 0       no
# 2       no
# 4       no
# 6      yes
# 7      yes

# %%
import re
df18[['city_mpg', 'hwy_mpg', 'cmb_mpg']] = df18[['city_mpg', 'hwy_mpg', 'cmb_mpg']].apply(lambda x: x.str.extract(r'(\d+)', expand=False).astype(float))
df18.head()
# Out:
#        model  displ  cyl       trans drive      fuel  veh_class  \
# 1  ACURA RDX    3.5    6  SemiAuto-6   2WD  Gasoline  small SUV
# 3  ACURA RDX    3.5    6  SemiAuto-6   4WD  Gasoline  small SUV
# 4  ACURA TLX    2.4    4       AMS-8   2WD  Gasoline  small car
# 6  ACURA TLX    3.5    6  SemiAuto-9   2WD  Gasoline  small car
# 8  ACURA TLX    3.5    6  SemiAuto-9   4WD  Gasoline  small car
#
#    air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score  \
# 1                  3.0      20.0     28.0     23.0                     5
# 3                  3.0      19.0     27.0     22.0                     4
# 4                  3.0      23.0     33.0     27.0                     6
# 6                  3.0      20.0     32.0     24.0                     5
# 8                  3.0      21.0     30.0     24.0                     5
#
#   smartway
# 1       No
# 3       No
# 4       No
# 6       No
# 8       No

# %% [markdown]
# Fix greenhouse_gas_score datatype
#
#     2008: convert from float to int.

# %%
# df8['greenhouse_gas_score'] = df8['greenhouse_gas_score'].astype(int)
# ValueError: invalid literal for int() with base 10: '7/6'

# Convert '7/6' to a decimal ratio
# eval() function to evaluate the expression and obtain the result directly.
ratio = eval('7/6')

# Replace the value in the DataFrame
df8['greenhouse_gas_score'] = df8['greenhouse_gas_score'].replace('7/6', ratio)

# %%
df8['greenhouse_gas_score'] = df8['greenhouse_gas_score'].astype(int)
df8.head()
# Out:
#        model  displ  cyl    trans drive      fuel    veh_class  \
# 0  ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline          SUV
# 2  ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline          SUV
# 4   ACURA RL    3.5    6  Auto-S5   4WD  Gasoline  midsize car
# 6   ACURA TL    3.2    6  Auto-S5   2WD  Gasoline  midsize car
# 7   ACURA TL    3.5    6  Auto-S5   2WD  Gasoline  midsize car
#
#    air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score  \
# 0                  7.0      15.0     20.0     17.0                     4
# 2                  7.0      17.0     22.0     19.0                     5
# 4                  7.0      16.0     24.0     19.0                     5
# 6                  7.0      18.0     26.0     21.0                     6
# 7                  7.0      17.0     26.0     20.0                     6
#
#   smartway
# 0       no
# 2       no
# 4       no
# 6      yes
# 7      yes

# %%
df8.dtypes == df18.dtypes
# Out:
# model                    True
# displ                    True
# cyl                      True
# trans                    True
# drive                    True
# fuel                     True
# veh_class                True
# air_pollution_score      True
# city_mpg                 True
# hwy_mpg                  True
# cmb_mpg                  True
# greenhouse_gas_score    False
# smartway                 True
# dtype: bool

# %%
# oh No ! greenhouse_gas_score are not the same !!!

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 986 entries, 0 to 2400
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 986 non-null    object
#  1   displ                 986 non-null    float64
#  2   cyl                   986 non-null    int32
#  3   trans                 986 non-null    object
#  4   drive                 986 non-null    object
#  5   fuel                  986 non-null    object
#  6   veh_class             986 non-null    object
#  7   air_pollution_score   986 non-null    float64
#  8   city_mpg              986 non-null    float64
#  9   hwy_mpg               986 non-null    float64
#  10  cmb_mpg               986 non-null    float64
#  11  greenhouse_gas_score  986 non-null    int32
#  12  smartway              986 non-null    object
# dtypes: float64(5), int32(2), object(6)
# memory usage: 100.1+ KB

# %%
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 794 entries, 1 to 1609
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 794 non-null    object
#  1   displ                 794 non-null    float64
#  2   cyl                   794 non-null    int32
#  3   trans                 794 non-null    object
#  4   drive                 794 non-null    object
#  5   fuel                  794 non-null    object
#  6   veh_class             794 non-null    object
#  7   air_pollution_score   794 non-null    float64
#  8   city_mpg              794 non-null    float64
#  9   hwy_mpg               794 non-null    float64
#  10  cmb_mpg               794 non-null    float64
#  11  greenhouse_gas_score  794 non-null    int64
#  12  smartway              794 non-null    object
# dtypes: float64(5), int32(1), int64(1), object(6)
# memory usage: 83.7+ KB

# %%
df8['greenhouse_gas_score'] = df8['greenhouse_gas_score'].astype('int64')

# %%
df8.dtypes == df18.dtypes
# Out:
# model                   True
# displ                   True
# cyl                     True
# trans                   True
# drive                   True
# fuel                    True
# veh_class               True
# air_pollution_score     True
# city_mpg                True
# hwy_mpg                 True
# cmb_mpg                 True
# greenhouse_gas_score    True
# smartway                True
# dtype: bool

# %%
# Save your final CLEAN datasets as new files!
df8.to_csv('clean_08.csv', index=False)
df18.to_csv('clean_18.csv', index=False)

# %% [markdown]
# # Exploring with Visuals

# %% [markdown]
# Compare the distributions of greenhouse gas score in 2008 and 2018.

# %%
df8.hist(figsize=(12,12));

# %%
df18.hist(figsize=(12,12));

# %% [markdown]
# How has the distribution of combined mpg changed from 2008 to 2018?

# %%
df8[['city_mpg','hwy_mpg','cmb_mpg']].plot(kind='hist');

# %%
df18[['city_mpg','hwy_mpg','cmb_mpg']].plot(kind='hist');

# %%
# Became more skewed to the right

# %% [markdown]
# Describe the correlation between displacement and combined mpg

# %%
df8.plot(x="displ", y="cmb_mpg", kind="scatter");

# %%
df18.plot(x="displ", y="cmb_mpg", kind="scatter");

# %%
# Negative Colleration

# %% [markdown]
# Describe the correlation between greenhouse gas score and combined mpg.

# %%
df8.plot(x="greenhouse_gas_score", y="cmb_mpg", kind="scatter");

# %%
df18.plot(x="greenhouse_gas_score", y="cmb_mpg", kind="scatter");

# %%
#  Positive Colleration

# %% [markdown]
# # Conclusions & Visuals

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Q1: Are more unique models using alternative sources of fuel? By how much?

# %%
df8.fuel.value_counts()
# Out:
# Gasoline       984
# CNG              1
# ethanol/gas      1
# Name: fuel, dtype: int64

# %%
df18.fuel.value_counts()
# Out:
# Gasoline                737
# Ethanol/Gas              26
# Diesel                   19
# Gasoline/Electricity     12
# Name: fuel, dtype: int64

# %% [markdown]
# Looks like the alternative sources of fuel available in 2008 are CNG and ethanol, and those in 2018 ethanol and electricity. (You can use Google if you weren't sure which ones are alternative sources of fuel!)

# %%
# how many unique models used alternative sources of fuel in 2008
alt_08 = df8.query('fuel in ["CNG", "ethanol/gas"]').model.nunique()
alt_08
# Out:
# 2

# %%
# how many unique models used alternative sources of fuel in 2018
alt_18 = df18.query('fuel in ["Ethanol/Gas", "Gasoline/Electricity"]').model.nunique()
alt_18
# Out:
# 26

# %%
plt.bar(["2008", "2018"], [alt_08, alt_18])
plt.title("Number of Unique Models Using Alternative Fuels")
plt.xlabel("Year")
plt.ylabel("Number of Unique Models");

# %% [markdown]
# Since 2008, the number of unique models using alternative sources of fuel increased by 24. We can also look at proportions.

# %%
# total unique models each year
total_08 = df8.model.nunique()
total_18 = df18.model.nunique()
total_08, total_18
# Out:
# (377, 357)

# %%
prop_08 = alt_08/total_08
prop_18 = alt_18/total_18
prop_08, prop_18
# Out:
# (0.005305039787798408, 0.07282913165266107)

# %%
plt.bar(["2008", "2018"], [prop_08, prop_18])
plt.title("Proportion of Unique Models Using Alternative Fuels")
plt.xlabel("Year")
plt.ylabel("Proportion of Unique Models");

# %% [markdown]
# Q2: How much have vehicle classes improved in fuel economy?

# %%
veh_08 = df8.groupby('veh_class').cmb_mpg.mean()
veh_08
# Out:
# veh_class
# SUV              18.471429
# large car        18.509091
# midsize car      21.601449
# minivan          19.117647
# pickup           16.277108
# small car        21.105422
# station wagon    22.366667
# van              14.952381
# Name: cmb_mpg, dtype: float64

# %%
veh_18 = df18.groupby('veh_class').cmb_mpg.mean()
veh_18
# Out:
# veh_class
# large car          23.000000
# midsize car        26.777778
# minivan            20.800000
# pickup             18.577465
# small SUV          23.721154
# small car          24.230216
# special purpose    18.500000
# standard SUV       17.626667
# station wagon      27.529412
# Name: cmb_mpg, dtype: float64

# %%
# how much they've increased by for each vehicle class
inc = veh_18 - veh_08
inc
# Out:
# veh_class
# SUV                     NaN
# large car          4.490909
# midsize car        5.176329
# minivan            1.682353
# pickup             2.300356
# small SUV               NaN
# small car          3.124794
# special purpose         NaN
# standard SUV            NaN
# station wagon      5.162745
# van                     NaN
# Name: cmb_mpg, dtype: float64

# %%
# only plot the classes that exist in both years
inc.dropna(inplace=True)
plt.subplots(figsize=(8, 5))
plt.bar(inc.index, inc)
plt.title('Improvements in Fuel Economy from 2008 to 2018 by Vehicle Class')
plt.xlabel('Vehicle Class')
plt.ylabel('Increase in Average Combined MPG');

# %% [markdown]
# Q3: What are the characteristics of SmartWay vehicles? Have they changed over time?

# %% [markdown]
# We can analyze this by filtering each dataframe by SmartWay classification and exploring these datasets.

# %%
# smartway labels for 2008
df8.smartway.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
# get all smartway vehicles in 2008
smart_08 = df8.query('smartway == "yes"')

# %%
# explore smartway vehicles in 2008
smart_08.describe()
# Out:
#             displ         cyl  air_pollution_score    city_mpg     hwy_mpg  \
# count  380.000000  380.000000           380.000000  380.000000  380.000000
# mean     2.602895    4.826316             7.268421   20.984211   28.413158
# std      0.623436    1.002025             0.970027    3.442672    3.075194
# min      1.300000    4.000000             6.000000   17.000000   22.000000
# 25%      2.275000    4.000000             7.000000   19.000000   26.000000
# 50%      2.400000    4.000000             7.000000   20.000000   28.000000
# 75%      3.000000    6.000000             7.000000   22.000000   30.000000
# max      5.000000    8.000000             9.000000   48.000000   45.000000
#
#           cmb_mpg  greenhouse_gas_score
# count  380.000000            380.000000
# mean    23.736842              6.868421
# std      3.060379              0.827338
# min     20.000000              6.000000
# 25%     22.000000              6.000000
# 50%     23.000000              7.000000
# ...

# %%
smart_08.hist(figsize=(12,12));

# %%
# smartway labels for 2018
df18.smartway.unique()
# Out:
# array(['No', 'Yes', 'Elite'], dtype=object)

# %%
# get all smartway vehicles in 2018
smart_18 = df18.query('smartway in ["Yes", "Elite"]')

# %%
smart_18.describe()
# Out:
#            displ        cyl  air_pollution_score   city_mpg    hwy_mpg  \
# count  97.000000  97.000000            97.000000  97.000000  97.000000
# mean    1.779381   3.938144             5.175258  30.123711  37.567010
# std     0.423266   0.428525             1.779573   5.238594   4.262011
# min     1.200000   3.000000             3.000000  25.000000  27.000000
# 25%     1.500000   4.000000             3.000000  27.000000  35.000000
# 50%     1.600000   4.000000             5.000000  28.000000  37.000000
# 75%     2.000000   4.000000             7.000000  30.000000  40.000000
# max     3.500000   6.000000             7.000000  51.000000  53.000000
#
#          cmb_mpg  greenhouse_gas_score
# count  97.000000             97.000000
# mean   32.938144              7.711340
# std     4.358455              1.060255
# min    26.000000              7.000000
# 25%    30.000000              7.000000
# 50%    32.000000              7.000000
# 75%    34.000000              8.000000
# ...

# %%
smart_18.hist(figsize=(12,12));

# %% [markdown]
# Q4: What features are associated with better fuel economy?

# %% [markdown]
# You can explore trends between cmb_mpg and the other features in this dataset, or filter this dataset like in the previous question and explore the properties of that dataset. For example, you can select all vehicles that have the top 50% fuel economy ratings like this.

# %%
top_08 = df8.query('cmb_mpg > cmb_mpg.mean()')
top_08.describe()
# Out:
#             displ         cyl  air_pollution_score    city_mpg     hwy_mpg  \
# count  518.000000  518.000000           518.000000  518.000000  518.000000
# mean     2.667181    4.888031             6.932432   20.322394   27.608108
# std      0.666034    1.034703             1.001580    3.199722    3.051919
# min      1.300000    4.000000             6.000000   17.000000   20.000000
# 25%      2.300000    4.000000             6.000000   18.000000   25.000000
# 50%      2.500000    4.000000             7.000000   20.000000   27.000000
# 75%      3.000000    6.000000             7.000000   21.000000   29.000000
# max      6.000000    8.000000             9.000000   48.000000   45.000000
#
#           cmb_mpg  greenhouse_gas_score
# count  518.000000            518.000000
# mean    22.996139              6.640927
# std      2.927886              0.805220
# min     20.000000              6.000000
# 25%     21.000000              6.000000
# 50%     22.000000              6.000000
# ...

# %%
top_18 = df18.query('cmb_mpg > cmb_mpg.mean()')
top_18.describe()
# Out:
#             displ         cyl  air_pollution_score    city_mpg     hwy_mpg  \
# count  366.000000  366.000000           366.000000  366.000000  366.000000
# mean     2.065847    4.174863             4.702186   25.032787   33.106557
# std      0.491637    0.684083             1.877435    4.407841    4.138309
# min      1.200000    3.000000             1.000000   20.000000   27.000000
# 25%      1.800000    4.000000             3.000000   22.000000   30.000000
# 50%      2.000000    4.000000             5.000000   24.000000   32.000000
# 75%      2.000000    4.000000             7.000000   27.000000   35.000000
# max      3.600000    6.000000             7.000000   51.000000   53.000000
#
#           cmb_mpg  greenhouse_gas_score
# count  366.000000            366.000000
# mean    28.057377              6.030055
# std      4.083309              1.237175
# min     24.000000              4.000000
# 25%     25.000000              5.000000
# 50%     27.000000              6.000000
# ...

# %% [markdown]
# ## Last Question!

# %% [markdown]
# Q5: For all of the models that were produced in 2008 that are still being produced in 2018, how much has the mpg improved and which vehicle improved the most?

# %% [raw]
# This is a question regarding models that were updated since 2008 and still being produced in 2018. In order to do this, we need a way to compare models that exist in both datasets. To do this, let's first learn about merges.

# %% [raw]
# Types of Merges
#     Inner Join - Use intersection of keys from both frames.
#     Outer Join - Use union of keys from both frames.
#     Left Join - Use keys from left frame only.
#     Right Join - Use keys from right frame only.

# %% [markdown]
#  1. Rename 2008 columns to distinguish from 2018 columns after the merge

# %%
# rename 2008 columns
df8.rename(columns=lambda x: x[:5] + "_2008", inplace=True)

# %%
# view to check names
df8.head()
# Out:
#   model_2008  displ_2008  cyl_2008 trans_2008 drive_2008 fuel_2008  \
# 0  ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 2  ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 4   ACURA RL         3.5         6    Auto-S5        4WD  Gasoline
# 6   ACURA TL         3.2         6    Auto-S5        2WD  Gasoline
# 7   ACURA TL         3.5         6    Auto-S5        2WD  Gasoline
#
#     veh_c_2008  air_p_2008  city__2008  hwy_m_2008  cmb_m_2008  green_2008  \
# 0          SUV         7.0        15.0        20.0        17.0           4
# 2          SUV         7.0        17.0        22.0        19.0           5
# 4  midsize car         7.0        16.0        24.0        19.0           5
# 6  midsize car         7.0        18.0        26.0        21.0           6
# 7  midsize car         7.0        17.0        26.0        20.0           6
#
#   smart_2008
# 0         no
# 2         no
# 4         no
# 6        yes
# 7        yes

# %%
# merge datasets
# df_combined = pd.concat([df_08,df_18]).... You can use this
# merge data
df_combined = df8.merge(df18, left_on='model_2008', right_on='model', how='inner')

# %%
# view to check merge
df_combined.head()
# Out:
#   model_2008  displ_2008  cyl_2008 trans_2008 drive_2008 fuel_2008  \
# 0  ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 1  ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 2    AUDI A3         2.0         4      Man-6        2WD  Gasoline
# 3    AUDI A3         2.0         4      Man-6        2WD  Gasoline
# 4    AUDI A3         2.0         4    Auto-S6        2WD  Gasoline
#
#       veh_c_2008  air_p_2008  city__2008  hwy_m_2008  ...       trans  drive  \
# 0            SUV         7.0        17.0        22.0  ...  SemiAuto-6    2WD
# 1            SUV         7.0        17.0        22.0  ...  SemiAuto-6    4WD
# 2  station wagon         7.0        21.0        29.0  ...       AMS-6    4WD
# 3  station wagon         7.0        21.0        29.0  ...       AMS-7    2WD
# 4  station wagon         7.0        22.0        29.0  ...       AMS-6    4WD
#
#        fuel  veh_class  air_pollution_score  city_mpg hwy_mpg cmb_mpg  \
# ...

# %%
df_combined.to_csv('combined_dataset.csv', index=False)

# %% [markdown]
# Q5: For all of the models that were produced in 2008 that are still being produced now, how much has the mpg improved and which vehicle improved the most?

# %% [markdown]
# 1. Create a new dataframe, model_mpg, that contain the mean combined mpg values in 2008 and 2018 for each unique model

# %%
# df_combined['model_mpg'] = df_combined[['cmb_m_2008','cmb_mpg']].mean()

# %%
# df_combined.head()

# The values will be NaN

# %% [markdown]
# To resolve this issue, you can use the skipna=True argument in the .mean() function. By default, skipna is set to True, which excludes NaN values from the calculation. & fillna for the combined cmb

# %%
df_combined['model_mpg'] = df_combined[['cmb_m_2008', 'cmb_mpg']].fillna(df_combined[['cmb_m_2008', 'cmb_mpg']].mean(skipna=True)).mean(axis=1)

# %%
df_combined.head()
# Out:
#   model_2008  displ_2008  cyl_2008 trans_2008 drive_2008 fuel_2008  \
# 0  ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 1  ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 2    AUDI A3         2.0         4      Man-6        2WD  Gasoline
# 3    AUDI A3         2.0         4      Man-6        2WD  Gasoline
# 4    AUDI A3         2.0         4    Auto-S6        2WD  Gasoline
#
#       veh_c_2008  air_p_2008  city__2008  hwy_m_2008  ...  drive      fuel  \
# 0            SUV         7.0        17.0        22.0  ...    2WD  Gasoline
# 1            SUV         7.0        17.0        22.0  ...    4WD  Gasoline
# 2  station wagon         7.0        21.0        29.0  ...    4WD  Gasoline
# 3  station wagon         7.0        21.0        29.0  ...    2WD  Gasoline
# 4  station wagon         7.0        22.0        29.0  ...    4WD  Gasoline
#
#    veh_class air_pollution_score  city_mpg  hwy_mpg cmb_mpg  \
# ...

# %% [markdown]
# 2. Create a new column, mpg_change, with the change in mpg
#
# Subtract the mean mpg in 2008 from that in 2018 to get the change in mpg

# %%
df_combined['mpg_change'] = df_combined[['city__2008','hwy_m_2008','cmb_m_2008']].fillna(df_combined[['city__2008','hwy_m_2008','cmb_m_2008']].mean()).values - df_combined[['city_mpg','hwy_mpg','cmb_mpg']].fillna(df_combined[['city_mpg','hwy_mpg','cmb_mpg']].mean()).values
df_combined.head()
# Out:
#   model_2008  displ_2008  cyl_2008 trans_2008 drive_2008 fuel_2008  \
# 0  ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 1  ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 2    AUDI A3         2.0         4      Man-6        2WD  Gasoline
# 3    AUDI A3         2.0         4      Man-6        2WD  Gasoline
# 4    AUDI A3         2.0         4    Auto-S6        2WD  Gasoline
#
#       veh_c_2008  air_p_2008  city__2008  hwy_m_2008  ...      fuel  \
# 0            SUV         7.0        17.0        22.0  ...  Gasoline
# 1            SUV         7.0        17.0        22.0  ...  Gasoline
# 2  station wagon         7.0        21.0        29.0  ...  Gasoline
# 3  station wagon         7.0        21.0        29.0  ...  Gasoline
# 4  station wagon         7.0        22.0        29.0  ...  Gasoline
#
#    veh_class air_pollution_score city_mpg  hwy_mpg  cmb_mpg  \
# 0  small SUV                 3.0     20.0     28.0     23.0
# ...

# %% [markdown]
# In this modified code, I've added .values at the end of both DataFrame slices to convert them into NumPy arrays. This ensures that the subtraction operation is performed element-wise between the two arrays, regardless of the column names.

# %% [markdown]
# 3. Find the vehicle that improved the most
#
# Find the max mpg change, and then use query or indexing to see what model it is!

# %%
max_change = df_combined['mpg_change'].max()
max_change
# Out:
# 5.0

# %%
df_combined[df_combined['mpg_change'] == max_change]
#  OR you can use query
# Out:
#         model_2008  displ_2008  cyl_2008 trans_2008 drive_2008 fuel_2008  \
# 171   CHRYSLER 300         2.7         6    Auto-L4        2WD  Gasoline
# 210  DODGE Charger         2.7         6    Auto-L4        2WD  Gasoline
#
#     veh_c_2008  air_p_2008  city__2008  hwy_m_2008  ...         fuel  \
# 171  large car         6.0        18.0        26.0  ...  Ethanol/Gas
# 210  large car         6.0        18.0        26.0  ...  Ethanol/Gas
#
#      veh_class air_pollution_score city_mpg  hwy_mpg  cmb_mpg  \
# 171  large car                 3.0     13.0     20.0     16.0
# 210  large car                 3.0     13.0     20.0     16.0
#
#     greenhouse_gas_score smartway model_mpg mpg_change
# 171                    4       No      18.5        5.0
# 210                    4       No      18.5        5.0
#
# [2 rows x 28 columns]
